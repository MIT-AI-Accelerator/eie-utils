# %%
# !apt update
# !apt upgrade
# !apt install gdal-bin python-gdal python3-gdal
# !pip install rasterio
# !pip install pyproj
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Get:6 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Ign:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# ...

# %%
# Out:
# m_3807504_ne_18_1_buildings.tif		m_3807504_ne_18_1_naip-new.tif
# m_3807504_ne_18_1_landsat-leaf-off.tif	m_3807504_ne_18_1_naip-old.tif
# m_3807504_ne_18_1_landsat-leaf-on.tif	m_3807504_ne_18_1_nlcd.tif
# m_3807504_ne_18_1_lc.tif

# %%
import os
from google.colab import drive
drive.mount('/content/drive')


# !ls "/content/drive/My Drive/EIE Side Projects/de_1m_2013/de_1m_2013_extended-test_tiles/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# m_3807504_ne_18_1_buildings.tif		m_3807504_ne_18_1_naip-new.tif
# m_3807504_ne_18_1_landsat-leaf-off.tif	m_3807504_ne_18_1_naip-old.tif
# m_3807504_ne_18_1_landsat-leaf-on.tif	m_3807504_ne_18_1_nlcd.tif
# m_3807504_ne_18_1_lc.tif

# %%
import rasterio
from matplotlib import pyplot

# Brandon
#fn = "/content/drive/Shared drives/EIE Side Projects/lu_data_upgrade/de_1m_2013_extended-test_tiles/m_3807504_ne_18_1_lu.tif" 

# Peter
folder = "/content/drive/My Drive/EIE Side Projects/de_1m_2013/de_1m_2013_extended-test_tiles/"

for file_name in ['m_3807504_ne_18_1_buildings.tif',
           'm_3807504_ne_18_1_naip-new.tif',
           'm_3807504_ne_18_1_landsat-leaf-off.tif',
           'm_3807504_ne_18_1_naip-old.tif',
           'm_3807504_ne_18_1_landsat-leaf-on.tif',
           'm_3807504_ne_18_1_nlcd.tif',
           'm_3807504_ne_18_1_lc.tif']:

  file_loc = folder + file_name

  with rasterio.open(file_loc, "r") as f:
    data = f.read()
    # print('width:', f.width, 'height:', f.height)
    # print('coordinates:', f.crs)
    # print('transform:\n', f.transform)
    # print('count:', f.count)
    # print('indexes:', f.indexes)
    # print('bounds:', f.bounds)

    print('raster:', f.meta)

    dataset = f

    # print(f.transform * (0, 0))
    pyplot.figure()
    pyplot.imshow(data[0,:,:])
# Out:
# raster: {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': None, 'width': 6056, 'height': 7569, 'count': 1, 'crs': CRS.from_epsg(26918), 'transform': Affine(1.0, 0.0, 450949.0,
#        0.0, -1.0, 4317228.0)}
# raster: {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': None, 'width': 6056, 'height': 7569, 'count': 4, 'crs': CRS.from_epsg(26918), 'transform': Affine(1.0, 0.0, 450949.0,
#        0.0, -1.0, 4317228.0)}
# raster: {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 6056, 'height': 7569, 'count': 9, 'crs': CRS.from_epsg(26918), 'transform': Affine(1.0, 0.0, 450949.0,
#        0.0, -1.0, 4317228.0)}
# raster: {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': None, 'width': 6056, 'height': 7569, 'count': 4, 'crs': CRS.from_epsg(26918), 'transform': Affine(1.0, 0.0, 450949.0,
#        0.0, -1.0, 4317228.0)}
# ...

# %%
import numpy as np

train_patch = np.load("/content/drive/My Drive/EIE Side Projects/de_1m_2013/de_1m_2013_extended-train_patches/de_1m_2013-m_3807503_ne_18_1-0.npz")

# %%
help(train_patch)
# Out:
# Help on NpzFile in module numpy.lib.npyio object:
#
# class NpzFile(collections.abc.Mapping)
#  |  NpzFile(fid)
#  |
#  |  A dictionary-like object with lazy-loading of files in the zipped
#  |  archive provided on construction.
#  |
#  |  `NpzFile` is used to load files in the NumPy ``.npz`` data archive
#  |  format. It assumes that files in the archive have a ``.npy`` extension,
#  |  other files are ignored.
#  |
#  |  The arrays and file strings are lazily loaded on either
#  |  getitem access using ``obj['key']`` or attribute lookup using
#  |  ``obj.f.key``. A list of all files (without ``.npy`` extensions) can
#  |  be obtained with ``obj.files`` and the ZipFile object itself using
#  |  ``obj.zip``.
#  |
#  |  Attributes
#  |  ----------
#  |  files : list of str
#  |      List of all files in the archive with a ``.npy`` extension.
#  |  zip : ZipFile instance
#  |      The ZipFile object initialized with the zipped archive.
#  |  f : BagObj instance
# ...

# %%
np.shape(train_patch['arr_0'])
# Out:
# (1, 29, 256, 256)
